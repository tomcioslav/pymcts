# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bridgit import Bridgit, GameState, Player
from bridgit.config import Config
from bridgit import schema

# %% [markdown]
# ### State

# %%
game_state = GameState.empty()

# %%
game_state.visualize()

# %%
new_move = game_state.make_move(1, 1, Player.HORIZONTAL)

# %%
new_move.visualize()

# %%
new_move.to_mask()

# %%
new_move.to_tensor()

# %%
canonical = new_move.canonical(Player.VERTICAL)

# %%
canonical.visualize()

# %% [markdown]
# ### Game

# %%
game = Bridgit()

# %%
game.visualize()

# %%
game.make_move(schema.Move(row=1, col=1))
game.visualize()
game.make_move(schema.Move(row=2, col=2))
game.visualize()
game.make_move(schema.Move(row=3, col=3))
game.visualize()
